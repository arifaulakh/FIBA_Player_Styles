# %% [markdown]
# ## Descriptive Analysis - Distribution of Statistics
#
# First, let's load the unmerged dataframe.

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('Filter_Unmerged.csv').drop(columns = ['Unnamed: 0'])
df.head()
# Out:
#       FULL NAME TEAM  POS    AGE  GP   MPG  MIN%  USG%  Tor%  FTA  ...  TOPG  \
# 0  Alex Abrines  Okc    G  25.69  31  19.0  39.5  12.2   7.9   13  ...  0.45
# 1  Jaylen Adams  Atl    G  22.93  34  12.6  26.2  13.5  19.7    9  ...  0.82
# 2  Steven Adams  Okc    C  25.73  80  33.4  69.5  16.4  12.8  292  ...  1.73
# 3   Bam Adebayo  Mia  C-F  21.73  82  23.3  48.6  15.8  17.1  226  ...  1.48
# 4     Deng Adel  Cle    F  22.19  19  10.2  21.3   9.9  13.7    4  ...  0.32
#
#     VI   ORTG   DRTG      2PM     3PM      FGM  FGA     PTS    MINS
# 0  3.5  103.1  103.9   15.000  41.021   56.021  157   164.3   589.0
# 1  7.0   99.5  108.1   12.996  25.012   38.008  110   108.8   428.4
# 2  7.1  119.9  102.7  480.972   0.000  480.972  809  1112.0  2672.0
# 3  9.0  120.0   97.2  276.948   3.000  279.948  486   729.8  1910.6
# 4  3.1   85.3  115.7    5.005   6.003   11.008   36    32.3   193.8
#
# [5 rows x 34 columns]

# %% [markdown]
# Now let's plot histograms showing the distribution of each of the stats.

# %%
cols = df.select_dtypes(include='number').columns
f = plt.subplots(8, 4, figsize=(18, 32))
for i in range(len(cols)):
    plt.subplot(8, 4, i+1)
    plt.hist(df[cols[i]], bins=20)
    plt.title(cols[i])
    plt.tight_layout()
plt.show()

# %% [markdown]
# Most of the stats appear to be skewed binomial distributions. Normalizing the statistics by assigning z-scores may not be appropriate for all stats. Special care must be taken with `FT%`, `2P%` and `3P%` due to the large number of zeros that don't fit in the distribution.
