# %%
import pandas as pd
df_FIBA = pd.read_csv("FIBA_Play_Counts.csv", encoding='latin-1')
df_FIBA.rename(columns={"Unnamed: 0": "Player"}, inplace=True)
df_FIBA['Source'] = 'FIBA'
df_FIBA.head()
# Out:
#                 Player  P&R Ball Handler  Spot-Up  Transition  ISO  Post-Up  \
# 0          Ricky Rubio               284      121          64   20        0
# 1           Luis Scola                 0      122         105   19      304
# 2       Rudy Fernandez               109      103          54   33        0
# 3  Juancho Hernangomez                 2       53          25    5        5
# 4        Pierre Oriola                 0       21          10    0        3
#
#    P&R Roll Man  Cut  Offensive Rebound  Off Screen  Hand Off  Total Source
# 0             0    9                 25           7        16    546   FIBA
# 1           167  125                 97          20         1    960   FIBA
# 2             1   20                 37          36        12    405   FIBA
# 3             8   26                 35          13         1    173   FIBA
# 4             8   18                 38           1         1    100   FIBA

# %%
df_NBA = pd.read_csv("NBA_Play_Counts.csv", encoding='latin-1')
df_NBA.rename(columns={"Unnamed: 0": "Player"}, inplace=True)
df_NBA['Source'] = 'NBA'
df_NBA.head()
# Out:
#           Player  P&R Ball Handler  Spot-Up  Transition   ISO  Post-Up  \
# 0    Dwyane Wade              4872      818        1207  1149     1232
# 1    Danny Green               751     2193        1168   127       42
# 2   Lebron James               863      199         477   612      514
# 3  Kawhi Leonard              3109     1734        1487  1471     1223
# 4     Tim Duncan                 6      280         169    98     1235
#
#    P&R Roll Man  Cut  Offensive Rebound  Off Screen  Hand Off  Total Source
# 0            26  484                437         396       364  10985    NBA
# 1            21  212                350         512       282   5658    NBA
# 2            64  121                 92          86         7   3035    NBA
# 3            60  310                605         523       463  10985    NBA
# 4           757  635                556          52        13   3801    NBA

# %%
df = pd.concat([df_FIBA, df_NBA]).reset_index()
s = df['Player'].value_counts()
df[df['Player'].isin(s[s>=2].index)]
# Out:
#       index             Player  P&R Ball Handler  Spot-Up  Transition  ISO  \
# 0         0        Ricky Rubio               284      121          64   20
# 1         1         Luis Scola                 0      122         105   19
# 2         2     Rudy Fernandez               109      103          54   33
# 6         6    Patricio Garino                28       80          73    6
# 7         7         Marc Gasol                 2       50          33   14
# ...     ...                ...               ...      ...         ...  ...
# 4531   1658     Luciano Parodi                10        1           1    3
# 4534   1661         Lucas Dias                 0        4           1    0
# 4535   1662  Carlos Schattmann                 6        0           1    0
# 4536   1663     Lucas Cipolini                 0        3           2    0
# 4539   1666         Xudong Luo                 4        2           0    1
#
#       Post-Up  P&R Roll Man  Cut  Offensive Rebound  Off Screen  Hand Off  \
# 0           0             0    9                 25           7        16
# 1         304           167  125                 97          20         1
# 2           0             1   20                 37          36        12
# 6          12             0   16                 20           7         7
# 7         166           115   52                 30           5         2
# ...       ...           ...  ...                ...         ...       ...
# 4531        0             0    0                  0           1         1
# 4534        5             1    0                  1           1         0
# 4535        0             0    0                  0           4         0
# 4536        2             0    0                  4           0         0
# 4539        0             0    0                  0           0         0
#
#       Total Source
# 0       546   FIBA
# 1       960   FIBA
# 2       405   FIBA
# 6       249   FIBA
# 7       469   FIBA
# ...     ...    ...
# 4531     17    NBA
# 4534     13    NBA
# 4535     11    NBA
# 4536     11    NBA
# 4539      7    NBA
#
# [786 rows x 14 columns]

# %%
play_types = ['P&R Ball Handler', 'Spot-Up', 'Transition', 'ISO', 'Post-Up', 'P&R Roll Man', 'Cut', 'Offensive Rebound', 'Off Screen', 'Hand Off']
for p in play_types:
    df['% ' + p] = df[p] / df['Total']

# %%
df = df[df['Total'] >= 50].sort_values('Total', ascending=False)
filt_df = df[['% ' + p for p in play_types]].copy()
filt_df
# Out:
#       % P&R Ball Handler  % Spot-Up  % Transition     % ISO  % Post-Up  \
# 3029            0.423124   0.044817      0.130192  0.302092   0.025178
# 2902            0.459019   0.054126      0.168658  0.156896   0.076152
# 2949            0.594455   0.053659      0.081796  0.142271   0.001794
# 2994            0.432533   0.080753      0.075427  0.158090   0.091635
# 3470            0.346271   0.045403      0.154897  0.217370   0.123510
# ...                  ...        ...           ...       ...        ...
# 2053            0.260000   0.320000      0.000000  0.040000   0.000000
# 193             0.060000   0.300000      0.180000  0.060000   0.020000
# 179             0.480000   0.160000      0.280000  0.040000   0.000000
# 3258            0.220000   0.160000      0.120000  0.160000   0.100000
# 3749            0.780000   0.060000      0.080000  0.060000   0.000000
#
#       % P&R Roll Man     % Cut  % Offensive Rebound  % Off Screen  % Hand Off
# 3029        0.001619  0.009969             0.021855      0.016274    0.024880
# 2902        0.000797  0.012793             0.043114      0.009185    0.019261
# 2949        0.000718  0.019116             0.019373      0.036593    0.050226
# 2994        0.001795  0.017135             0.024428      0.080926    0.037279
# 3470        0.017191  0.035160             0.034981      0.011680    0.013537
# ...              ...       ...                  ...           ...         ...
# 2053        0.000000  0.000000             0.020000      0.300000    0.060000
# 193         0.000000  0.100000             0.260000      0.020000    0.000000
# 179         0.000000  0.000000             0.000000      0.020000    0.020000
# 3258        0.040000  0.060000             0.080000      0.060000    0.000000
# 3749        0.000000  0.000000             0.000000      0.000000    0.020000
#
# [2292 rows x 10 columns]

# %%
from sklearn.cluster import KMeans
inertias = []
for i in range(5, 15):
    test_model = KMeans(n_clusters=i)
    test_model.fit(filt_df)
    inertias.append(test_model.inertia_)
print(inertias)
# Out:
# [57.58327198346059, 51.59621555295966, 46.56425390027253, 44.21412372972801, 42.271441777209205, 40.56919619543621, 38.93175384701325, 37.37455107423202, 35.997344811513116, 34.61907310801569]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,4))
plt.plot(range(5,15), inertias, 'bx-')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('The Elbow Method showing the optimal k')
plt.show()

# %%
num_clusters = 7
test_model = KMeans(n_clusters=num_clusters)
test_model.fit(filt_df)
filt_df['Cluster'] = test_model.labels_
filt_df['Cluster'].value_counts()
# Out:
# 5    417
# 1    403
# 3    355
# 0    348
# 6    300
# 4    262
# 2    207
# Name: Cluster, dtype: int64

# %%
df['Cluster'] = test_model.labels_

# %%
for i in range(num_clusters):
    print("Cluster "+ str(i))
    print(list(df['Player'].loc[filt_df[filt_df['Cluster'] == i].head(15).index]))
    print()
# Out:
# Cluster 0
# ['Trevor Ariza', 'Jae Crowder', 'Danny Green', 'DeMarre Carroll', 'Robert Covington', 'PJ Tucker', 'Al Farouq Aminu', 'Wilson Chandler', 'Marvin Williams', 'Nikola Mirotic', 'CJ Miles', 'Jaylen Brown', 'Corey Brewer', 'Michael Kidd-Gilchrist', 'Allen Crabbe']
#
# Cluster 1
# ['James Harden', 'Russell Westbrook', 'DeMar DeRozan', 'LeBron James', 'Stephen Curry', 'Bradley Beal', 'Kyle Lowry', 'Paul George', 'Jimmy Butler', 'CJ McCollum', 'Dwyane Wade', 'Andrew Wiggins', 'Eric Bledsoe', 'Gordon Hayward', 'Victor Oladipo']
#
# Cluster 2
# ['LaMarcus Aldridge', 'Blake Griffin', 'DeMarcus Cousins', 'Nikola Vucevic', 'Marc Gasol', 'Karl-Anthony Towns', 'Al Horford', 'Brook Lopez', 'Enes Kanter', 'Zach Randolph', 'Dirk Nowitzki', 'Nikola Jokic', 'Pau Gasol', 'Dwight Howard', 'Jonas Valanciunas']
#
# Cluster 3
# ['Damian Lillard', 'Kemba Walker', 'Chris Paul', 'John Wall', 'Kyrie Irving', 'Jeff Teague', 'Goran Dragic', 'Dennis Schroder', 'Isaiah Thomas', 'Jrue Holiday', 'Reggie Jackson', 'Mike Conley', 'Ricky Rubio', 'Tony Parker', 'Derrick Rose']
#
# Cluster 4
# ['Andre Drummond', 'Derrick Favors', 'Steven Adams', 'Marcin Gortat', 'DeAndre Jordan', 'Robin Lopez', 'Tristan Thompson', 'Mason Plumlee', 'Hassan Whiteside', 'Rudy Gobert', 'Clint Capela', 'Gorgui Dieng', 'Myles Turner', 'Kenneth Faried', 'Alex Len']
#
# Cluster 5
# ['Kevin Durant', 'Giannis Antetokounmpo', 'Klay Thompson', 'Kawhi Leonard', 'Carmelo Anthony', 'Tobias Harris', 'Khris Middleton', 'Eric Gordon', 'Rudy Gay', 'JJ Redick', 'Marcus Morris', 'Avery Bradley', 'Jeff Green', 'Joe Johnson', 'Wesley Matthews']
#
# Cluster 6
# ['Anthony Davis', 'Paul Millsap', 'Kevin Love', 'Harrison Barnes', 'Thaddeus Young', 'Serge Ibaka', 'Draymond Green', 'Markieff Morris', 'Julius Randle', 'Ersan Ilyasova', 'Kelly Olynyk', 'Jabari Parker', 'Jerami Grant', 'Ryan Anderson', 'Luol Deng']

# %%
filt_df.groupby('Cluster').mean()
# Out:
#          % P&R Ball Handler  % Spot-Up  % Transition     % ISO  % Post-Up  \
# Cluster
# 0                  0.020080   0.250238      0.109212  0.053111   0.150097
# 1                  0.228358   0.247098      0.178156  0.073313   0.025603
# 2                  0.602623   0.120243      0.093830  0.081426   0.004219
# 3                  0.425056   0.181955      0.137770  0.083817   0.013274
# 4                  0.003838   0.082352      0.065061  0.032017   0.356926
# 5                  0.077976   0.381222      0.166869  0.037926   0.034387
# 6                  0.004074   0.076636      0.080813  0.022122   0.126755
#
#          % P&R Roll Man     % Cut  % Offensive Rebound  % Off Screen  \
# Cluster
# 0              0.131104  0.112577             0.137590      0.026617
# 1              0.006045  0.043316             0.059344      0.088705
# 2              0.000545  0.013095             0.029760      0.022419
# 3              0.001606  0.027624             0.046259      0.044391
# 4              0.137628  0.143162             0.168395      0.008519
# 5              0.033488  0.070911             0.105822      0.059232
# 6              0.186795  0.224769             0.270755      0.004514
#
#          % Hand Off
# Cluster
# 0          0.009372
# 1          0.050061
# 2          0.031838
# 3          0.038249
# 4          0.002102
# 5          0.032167
# 6          0.002766

# %%
s = df['Player'].value_counts()
names_to_keep = s[s >= 2].index

filt_df = df[df['Player'].isin(names_to_keep)]

nba_df = filt_df[filt_df['Source'] == 'NBA'].sort_values('Player')
fiba_df = filt_df[filt_df['Source'] == 'FIBA'].sort_values('Player')
if False in nba_df['Player'].values == fiba_df['Player'].values:
    print("Some names do not match!")
else:
    print("All names match! Ready to create confusion matrix.")
# Out:
# All names match! Ready to create confusion matrix.

# %%
fiba_df.shape
# Out:
# (164, 25)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(nba_df['Cluster'].values, fiba_df['Cluster'].values)
pd.DataFrame(cm)
# Out:
#     0   1   2   3   4  5   6
# 0  13   0   0   0   4  1   5
# 1   4  13   3   2   1  2   0
# 2   0   1  18  10   0  0   0
# 3   0   9   3  12   0  0   0
# 4   1   0   0   0   8  0   1
# 5   5   9   0   0   0  9   0
# 6   2   0   0   0  12  0  16

# %%
import numpy as np
sum(np.diag(cm))/sum(sum(cm))
# Out:
# 0.5426829268292683

# %%
fiba_df[['% ' + p for p in play_types]].mean()
# Out:
# % P&R Ball Handler     0.202813
# % Spot-Up              0.166301
# % Transition           0.119805
# % ISO                  0.069373
# % Post-Up              0.115954
# % P&R Roll Man         0.067716
# % Cut                  0.087666
# % Offensive Rebound    0.106358
# % Off Screen           0.043414
# % Hand Off             0.020601
# dtype: float64

# %%
nba_df[['% ' + p for p in play_types]].mean()
# Out:
# % P&R Ball Handler     0.220353
# % Spot-Up              0.178930
# % Transition           0.110556
# % ISO                  0.057706
# % Post-Up              0.078116
# % P&R Roll Man         0.083510
# % Cut                  0.084898
# % Offensive Rebound    0.109814
# % Off Screen           0.043644
# % Hand Off             0.032472
# dtype: float64

# %%
plt.figure(figsize = (16,8))
plt.bar([i for i in range(10)], fiba_df[['% ' + p for p in play_types]].mean(), width = 0.35, label = 'FIBA')
plt.bar([i+0.35 for i in range(10)], nba_df[['% ' + p for p in play_types]].mean(), width = 0.35, label = 'NBA')
plt.xticks([i+0.175 for i in range(10)], play_types)
plt.legend()
plt.show()
